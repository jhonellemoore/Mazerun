# %%
print("hello world!")
# Out:
# hello world!

# %%
def square_add_two(x):
  return x**2 + 2

# write
# as
# many
# lines
# as 
# you
# want

# %%
# This is a comment
square_add_two(5)
# Out:
# 27

# %% [markdown]
# # Rendering Graphics

# %%
import numpy
